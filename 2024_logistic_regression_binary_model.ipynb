# %% [markdown]
# <a href="https://colab.research.google.com/github/gompaalisha/ML_codes/blob/main/2024_logistic_regression_binary_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 style="color:green" align="center">Predicting if a person would buy life insurnace based on his age using logistic regression</h2>

# %% [markdown]
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 27   46
# 11   28
# 25   54
# 19   18
# 26   23
# 3    52

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 27   46
# 11   28
# 25   54
# 19   18
# 26   23
# 3    52

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.17761612, 0.82238388],
#        [0.76005464, 0.23994536],
#        [0.06144692, 0.93855308],
#        [0.93369954, 0.06630046],
#        [0.86977473, 0.13022527],
#        [0.08107946, 0.91892054]])

# %%
model.score(X_test,y_test)
# Out:
# 0.6666666666666666

# %%
y_predicted
# Out:
# array([1, 0, 1, 0, 0, 1])

# %%
X_test
# Out:
#     age
# 27   46
# 11   28
# 25   54
# 19   18
# 26   23
# 3    52

# %% [markdown]
# **model.coef_ indicates value of m in y=m*x + b equation**

# %%
model.coef_
# Out:
# array([[0.14919788]])

# %% [markdown]
# **model.intercept_ indicates value of b in y=m*x + b equation**

# %%
model.intercept_
# Out:
# array([-5.33051965])
